# %%
import n
import d

name = input("กรุณากรอกชื่อ: ")
score = int(input("กรุณากรอกคะแนน: "))

grade = d.calScore(score)
n.show_name(name)

print("เกรดที่ได้:", grade)
# Out:
# กรุณากรอกชื่อ: kl
# กรุณากรอกคะแนน: 70
# ชื่อนักศึกษา: kl
# เกรดที่ได้: B
