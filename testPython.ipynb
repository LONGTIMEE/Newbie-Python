# %%
a=b=c=12
print(a)

# %%
a=b=c=12
print(a)

# %%
x=input 
x=str()
if (x==12):
    print("ผ่านเงื่อนไข")
else:
    print("ไม่ผ่าน")

# %%
# x=0.3
# x=str()
# print(type(x))
-------------------
x="7"
x=int()
print(type(x))

# %%
# x =(8,9,4) Tuple
# x =[8,9,4] list

# %%
x=3
if x==3 :
    print("สวัสดี")
else :
    print("ไม่สวัสดีก")

# %%
a=input("กรอกชื่อของคุณ: ")

print("สวัสดีครับ ผู้ช่วยศาสตราจารย์ ดร."+a)

# %%
# opertor +,-,*,/

# %%
# input รับค่ามาเป็น str หมด

# age = int(input("กรอกอายุ:"))
# print(type(age)) เอาค่ามาใช้ไม่ได้

# x = input("กรุณาใส่อายุ: ")
# x = int(x) เอาค่ามาใช้ต่อได้

# %%
# u = 4**4
# print(u)

# %%
# != คือไม่ /// ไม่รองรับ<>

# %%
a = int(input())
b = int(input())
sum = a * b
print("พื้นที่สี่เหลี่ยม= ", sum)

# %%
a = int(input("คะเเนนกลางภาค:"))
b = int(input("คะเเนนปลายภาค:"))
c = int(input("คะเเนนเข้าเรียน:"))
score=a+b+c

if score>=80 :
    print("A")
elif score>=70 :
    print("B")
elif score>=60 :
    print("C")
elif score>=50 :
    print("D")
else :
    print("ยินดีด้วยคุณตั้งใจเรียนมากๆ")
# Out:
# คะเเนนกลางภาค:35
# คะเเนนปลายภาค:35
# คะเเนนเข้าเรียน:20
# A

# %%
a=lambda x,y,z: x+y+z #x,y,zเป็นparameter:x+y+z(คำสั่ง)
print(a(5,3,1))

# %%
#if
x=3
y=1
if x==0 :
    print("x is zero")
elif y==0 :
    print("y is zero")
else: 
    print("Error")

# %%
#while
x=0
while x<5 :
    print(x)
    x=x+1 # i++
else : # 
    print("Bye Bye")

# %%
x=[1,2,3,4,5,"6"]
y=["a","b","c"]
z=(1,2,3,5)
# print(type(x[5]))
print(type(z))

# %%
for a in x:
    print("value in x is:", a)

# %%
for a in range(len(x)) :
    print("value is:", a)

# %%
for a in range(3) :
    print("Value is:", a)

# %%
a= "string"
y= "test"
print(a,y)

# %%
z=[]
z.append((a,y))
print(z)

# %%
j=[]
a = int(input())
b = int(input())
c = int(input())
d = int(input())
e = int(input())

j=[a,b,c,d,e]


print(j)
for g in j:
    print("value in x is:", g)
# Out:
# 4
# 8
# 9
# 1
# 2
# [4, 8, 9, 1, 2]
# value in x is: 4
# value in x is: 8
# value in x is: 9
# value in x is: 1
# value in x is: 2

# %%
a=lambda x,y,z: x+y+z #x,y,zเป็นparameter:x+y+z(คำสั่ง)
print(a(5,3,1))

# %%
scores = [] # ใช้ชื่อตัวแปรให้สื่อความหมายมากขึ้น
num_scores = 5

for i in range(num_scores):
    # รับค่าคะแนนทีละตัวใน Loop
    try:
        score = int(input(f"กรอกคะแนนค่าที่ {i + 1}: "))
        scores.append(score)
    except ValueError:
        print("⚠️ กรุณากรอกเป็นจำนวนเต็มเท่านั้น!")

print(f"\nList ที่เก็บคะแนน: {scores}")
print("--- แสดงผลคะแนนแต่ละค่า ---")

# Loop จะทำงานตามจำนวนคะแนนที่รับมา
for g in scores:
    print("คะแนนคือ:", g)
# Out:
# กรอกคะแนนค่าที่ 1: 4
# กรอกคะแนนค่าที่ 2: 5
# กรอกคะแนนค่าที่ 3: 7
# กรอกคะแนนค่าที่ 4: 9
# กรอกคะแนนค่าที่ 5: 3
#
# List ที่เก็บคะแนน: [4, 5, 7, 9, 3]
# --- แสดงผลคะแนนแต่ละค่า ---
# คะแนนคือ: 4
# คะแนนคือ: 5
# คะแนนคือ: 7
# คะแนนคือ: 9
# คะแนนคือ: 3

# %%
n = int(input("ต้องการรับกี่ค่า: "))

items = []
for i in range(n):
    x = input(f"ค่าที่ {i+1}: ")
    items.append(x)

print(items)
# Out:
# ต้องการรับกี่ค่า: 5
# ค่าที่ 1: 4
# ค่าที่ 2: 8
# ค่าที่ 3: 9
# ค่าที่ 4: 6
# ค่าที่ 5: 1
# ['4', '8', '9', '6', '1']

# %%
# 9/12/2568 week4

# เริ่มเเรก
# def babFunc():
#     x=10
#     y=x+1
#     print(y)

# babFunc()    

# รอบสอง
# def babaFunc(x):
#     y=x+1
#     print(y)
    
# a=10    
# babaFunc(a)

# รอบสาม
# def babaFunc(x):
#     y=x+1
#     print(y)
#     return(y)
#     return 0
    
# a=10    
# babaFunc(a)

# รอบสี่
# def babaFunc(x):
#     y=x+1
#     print(y)
    
# a=int(input("pls Input Value: "))   
# babaFunc(a)

# รอบห้า
# lis=[2,9,7,9] #list +-*/ ไม่ได้
# def babaFunc(x):
#     print(x)
# babaFunc(lis)    

#รอบหก
# def testAUG(*abc):
#     for x in abc:
#         print(abc)
        
# testAUG(1,5,8,7,9)
# testAUG("1","5","8","7","9")
# testAUG([1,5,8,7,9])

#รอบเจ็ด
# a=lambda x,y,z: x+y+z #x,y,zเป็นparameter:x+y+z(คำสั่ง)
# print(a(5,3,1))

#รอบเเปด
# a = lambda x,y,z: x+y+"\n"+z #ใช้กับการส่งparameterทุกครั้ง ถ้าไม่มีใช้ไม่ได้
# print(a("sleep","morning","bababa"))

#รอบเก้า
# a = lambda x,y,z: x+y+z #ข้อสังเกตุส่ง ส่งparameter ไป ไม่รู้type ทั้งชุดต้องเป็นtypeเดียวกันทั้งหมด เเบบgroupส่งไปเเบบนี้ไม่ผ่านเเน่ 
# print(a("sleep","morning",9))

# เเบบฝึกหัด1
# def toTalFunc(x):
#     if a >= 60000 :
#         return a*0.1
#     elif a>=50000 :
#         return a*0.07
#     elif a>=40000 :
#         return a*0.05
#     else :
#         return a*0.03
       
    
    
# a=int(input("pls Input Value: "))   
# toTalFunc(a)
# Out:
# pls Input Value: 1
# 0.03

# %%
# 9/12/2568 week4

# เเบบฝึกหัด2
# grade = lambda total: \
#     "A" if total >= 80 else \
#     "B" if total >= 70 else \
#     "C" if total >= 60 else \
#     "D" if total >= 50 else "F"

# # รับคะแนน 3 ค่า
# try:
#     s1 = int(input("กรอกคะแนนกลางภาค: "))
#     s2 = int(input("กรอกคะแนนปลายภาค: "))
#     s3 = int(input("กรอกคะแนนเก็บ: "))
    
#     total = s1 + s2 + s3
#     print(f"\nคะแนนรวม = {total}")
#     print(f"เกรดที่ได้รับ = {grade(total)}")

# except:
#     print("กรอกข้อมูลไม่ถูกต้อง ต้องเป็นตัวเลขเท่านั้น!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f80c4c8f1a78> in <module>()
# ----> 1 เเบบฝึกหัด2
#       2 grade = lambda total:     "A" if total >= 80 else     "B" if total >= 70 else     "C" if total >= 60 else     "D" if total >= 50 else "F"
#       3
#       4 # รับคะแนน 3 ค่า
#       5 try:
#
# NameError: name 'เเบบฝึกหัด2' is not defined

# %%
# 16/12/2568 week5
# Contents
# Modules
# Packges
# สร้างไฟล์ใหม่ ดึงPackges เก่าได้
# โปรเเกรมย่อยๆ ในpack เรียกว่า modules ก็ได้หรือ เรียกว่า function
# modules มีจากpython
# สร้างขึ้นมาเอง
# modules ประกอบ fun class ตัวเเปร
# วิธีเรียกใช้ modules
# ใช้import
# packm1 เรียกหา m2
# ต้องเป็นชื่อmodule.py เท่านั้น
